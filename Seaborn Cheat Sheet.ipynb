# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# I used the AllStateData for practice, but my CapStone will be on Housing Data, AllState doesn't tell you what cont6 or cat42 mean.

# %%
allstate = pd.read_csv("/home/matthew/My Code/SpringBoard/AllStateData.csv")
print (allstate)
# Out:
#             id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9    ...     \
# 0            1    A    B    A    B    A    A    A    A    B    ...
# 1            2    A    B    A    A    A    A    A    A    B    ...
# 2            5    A    B    A    A    B    A    A    A    B    ...
# 3           10    B    B    A    B    A    A    A    A    B    ...
# 4           11    A    B    A    B    A    A    A    A    B    ...
# 5           13    A    B    A    A    A    A    A    A    B    ...
# 6           14    A    A    A    A    B    A    A    A    A    ...
# 7           20    A    B    A    B    A    A    A    A    B    ...
# 8           23    A    B    B    B    B    A    A    A    B    ...
# 9           24    A    B    A    A    B    B    A    A    B    ...
# 10          25    A    B    A    A    A    A    A    A    B    ...
# 11          33    A    B    A    A    B    A    A    A    B    ...
# 12          34    B    A    A    A    B    A    A    A    A    ...
# ...

# %%
sns.boxplot(allstate.cat42, allstate.cont6)
plt.show()

# %%
sns.kdeplot(allstate.cont6.dropna(), shade=True)
plt.show()
# Out:
# /home/matthew/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.distplot(allstate.cont6.dropna())
plt.show()
# Out:
# /home/matthew/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.violinplot(allstate.cont6.dropna())
plt.show()

# %%
sns.violinplot(allstate.cont6.dropna(), allstate.cat12) # Looks like cat12 those who were 'A' had a slighltly higher cont6.
plt.show()

# %%
sns.kdeplot(allstate.cont6.dropna(), cumulative=True) # so at 0.6 on the x axis. Roughly  70% of numbers fell below 0.6
plt.show() #What is the x-axis for this graph? When would you use a kde plot?
# Out:
# /home/matthew/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
